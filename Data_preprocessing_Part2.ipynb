# %% [markdown]
# <a href="https://colab.research.google.com/github/pinu9503/Real-estate-Project/blob/main/Data_preprocessing_Part2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('/content/gurgaon_com_clean_csv_j')

# %%
df.head()
# Out:
#                             property_name property_type               society  \
# 0        4 BHK Flat in Sector 112 Gurgaon          flat   experion windchants
# 1         3 BHK Flat in Sector 67 Gurgaon          flat            m3m merlin
# 2         3 BHK Flat in Sector 65 Gurgaon          flat        m3m golfestate
# 3         2 BHK Flat in Sector 85 Gurgaon          flat           ss the leaf
# 4  5 Bedroom House for sale in Bhim Nagar         house  bhim nagar, sector 6
#
#    price  price_per_sqft    area  \
# 0   5.60         11529.0  4857.0
# 1   2.90         14167.0  2047.0
# 2   6.10         18138.0  3363.0
# 3   1.05          6163.0  1704.0
# 4   0.85        126865.0    67.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0  Super Built up area 4857(451.23 sq.m.)Built Up...        4         6
# 1             Super Built up area 2047(190.17 sq.m.)        3         3
# 2  Super Built up area 3363(312.43 sq.m.)Carpet a...        3         3
# 3             Super Built up area 1671(155.24 sq.m.)        2         2
# 4                           Plot area 67(6.22 sq.m.)        5         2
#
#   balcony           additionalRoom  \
# 0      3+             servant room
# 1       3                   others
# 2       3  study room,servant room
# 3      3+               store room
# 4       2               pooja room
#
#                                              address  floorNum      facing  \
# 0         0000, Sector 112 Gurgaon, Gurgaon, Haryana      15.0  North-East
# 1                Sector 67 Gurgaon, Gurgaon, Haryana       0.0        West
# 2                Sector 65 Gurgaon, Gurgaon, Haryana      19.0  North-East
# 3  Sector 85 Gurgaon, Sector 85 Gurgaon, Gurgaon,...       7.0        West
# 4            H.N0- 159, Bhim Nagar, Gurgaon, Haryana       1.0         NaN
#
#       agePossession                                    nearbyLocations  \
# 0  5 to 10 Year Old  ['Ansal Plaza', 'Dwaraka Expressway', 'First S...
# 1   1 to 5 Year Old  ['Airia Mall', 'Golf Course Extension Road', '...
# 2  5 to 10 Year Old  ['Sector 54 Chowk Metro Station', 'Sahara Mall...
# 3   1 to 5 Year Old  ['Sapphire 83 Mall', 'Dwarka Expressway', 'Cen...
# 4      10+ Year Old  ['Chintapurni Mandir', 'Sheetla Mata Mandir', ...
#
#                                          description  \
# 0  Looking for a 4 bhk property for sale in gurga...
# 1  This 3 bhk flat is located in m3m merlin, whic...
# 2  M3m golfestate is one of gurgaon's most sought...
# 3  Ss the leaf by ss group offers the plan that i...
# 4  Hello all,This is good property where we spent...
#
#                                       furnishDetails  \
# 0  ['5 Wardrobe', '1 Water Purifier', '12 Fan', '...
# 1  ['3 Wardrobe', '5 Fan', '1 Exhaust Fan', '3 Ge...
# 2  ['4 Wardrobe', '5 Fan', '1 Exhaust Fan', '5 Ge...
# 3  ['2 AC', 'No Bed', 'No Chimney', 'No Curtains'...
# 4                                                NaN
#
#                                             features  \
# 0  ['Water purifier', 'Security / Fire Alarm', 'F...
# 1  ['Feng Shui / Vaastu Compliant', 'Security / F...
# 2  ['Centrally Air Conditioned', 'Water purifier'...
# 3  ['Security / Fire Alarm', 'Intercom Facility',...
# 4  ['Water Storage', 'No open drainage around', '...
#
#                                               rating
# 0  ['Green Area5 out of 5', 'Amenities5 out of 5'...
# 1  ['Green Area4 out of 5', 'Construction4 out of...
# 2  ['Green Area5 out of 5', 'Construction5 out of...
# 3  ['Green Area4.5 out of 5', 'Construction4.5 ou...
# 4  ['Environment3 out of 5', 'Lifestyle4 out of 5...

# %%
df.shape
# Out:
# (3961, 20)

# %%
#check duplicate value
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3961 entries, 0 to 3960
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    3961 non-null   object
#  1   property_type    3961 non-null   object
#  2   society          3960 non-null   object
#  3   price            3941 non-null   float64
#  4   price_per_sqft   3941 non-null   float64
#  5   area             3941 non-null   float64
#  6   areaWithType     3961 non-null   object
#  7   bedRoom          3961 non-null   int64
#  8   bathroom         3961 non-null   int64
#  9   balcony          3961 non-null   object
#  10  additionalRoom   3961 non-null   object
#  11  address          3950 non-null   object
#  12  floorNum         3940 non-null   float64
#  13  facing           2784 non-null   object
#  14  agePossession    3960 non-null   object
#  15  nearbyLocations  3754 non-null   object
#  16  description      3961 non-null   object
#  17  furnishDetails   2929 non-null   object
#  18  features         3252 non-null   object
#  19  rating           3511 non-null   object
# dtypes: float64(4), int64(2), object(14)
# memory usage: 619.0+ KB

# %%
#check null value
df.isnull().sum()
# Out:
# property_name         0
# property_type         0
# society               1
# price                20
# price_per_sqft       20
# area                 20
# areaWithType          0
# bedRoom               0
# bathroom              0
# balcony               0
# additionalRoom        0
# address              11
# floorNum             21
# facing             1177
# agePossession         1
# nearbyLocations     207
# description           0
# furnishDetails     1032
# features            709
# rating              450
# dtype: int64

# %%
df.head()
# Out:
#                             property_name property_type               society  \
# 0        4 BHK Flat in Sector 112 Gurgaon          flat   experion windchants
# 1         3 BHK Flat in Sector 67 Gurgaon          flat            m3m merlin
# 2         3 BHK Flat in Sector 65 Gurgaon          flat        m3m golfestate
# 3         2 BHK Flat in Sector 85 Gurgaon          flat           ss the leaf
# 4  5 Bedroom House for sale in Bhim Nagar         house  bhim nagar, sector 6
#
#    price  price_per_sqft    area  \
# 0   5.60         11529.0  4857.0
# 1   2.90         14167.0  2047.0
# 2   6.10         18138.0  3363.0
# 3   1.05          6163.0  1704.0
# 4   0.85        126865.0    67.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0  Super Built up area 4857(451.23 sq.m.)Built Up...        4         6
# 1             Super Built up area 2047(190.17 sq.m.)        3         3
# 2  Super Built up area 3363(312.43 sq.m.)Carpet a...        3         3
# 3             Super Built up area 1671(155.24 sq.m.)        2         2
# 4                           Plot area 67(6.22 sq.m.)        5         2
#
#   balcony           additionalRoom  \
# 0      3+             servant room
# 1       3                   others
# 2       3  study room,servant room
# 3      3+               store room
# 4       2               pooja room
#
#                                              address  floorNum      facing  \
# 0         0000, Sector 112 Gurgaon, Gurgaon, Haryana      15.0  North-East
# 1                Sector 67 Gurgaon, Gurgaon, Haryana       0.0        West
# 2                Sector 65 Gurgaon, Gurgaon, Haryana      19.0  North-East
# 3  Sector 85 Gurgaon, Sector 85 Gurgaon, Gurgaon,...       7.0        West
# 4            H.N0- 159, Bhim Nagar, Gurgaon, Haryana       1.0         NaN
#
#       agePossession                                    nearbyLocations  \
# 0  5 to 10 Year Old  ['Ansal Plaza', 'Dwaraka Expressway', 'First S...
# 1   1 to 5 Year Old  ['Airia Mall', 'Golf Course Extension Road', '...
# 2  5 to 10 Year Old  ['Sector 54 Chowk Metro Station', 'Sahara Mall...
# 3   1 to 5 Year Old  ['Sapphire 83 Mall', 'Dwarka Expressway', 'Cen...
# 4      10+ Year Old  ['Chintapurni Mandir', 'Sheetla Mata Mandir', ...
#
#                                          description  \
# 0  Looking for a 4 bhk property for sale in gurga...
# 1  This 3 bhk flat is located in m3m merlin, whic...
# 2  M3m golfestate is one of gurgaon's most sought...
# 3  Ss the leaf by ss group offers the plan that i...
# 4  Hello all,This is good property where we spent...
#
#                                       furnishDetails  \
# 0  ['5 Wardrobe', '1 Water Purifier', '12 Fan', '...
# 1  ['3 Wardrobe', '5 Fan', '1 Exhaust Fan', '3 Ge...
# 2  ['4 Wardrobe', '5 Fan', '1 Exhaust Fan', '5 Ge...
# 3  ['2 AC', 'No Bed', 'No Chimney', 'No Curtains'...
# 4                                                NaN
#
#                                             features  \
# 0  ['Water purifier', 'Security / Fire Alarm', 'F...
# 1  ['Feng Shui / Vaastu Compliant', 'Security / F...
# 2  ['Centrally Air Conditioned', 'Water purifier'...
# 3  ['Security / Fire Alarm', 'Intercom Facility',...
# 4  ['Water Storage', 'No open drainage around', '...
#
#                                               rating
# 0  ['Green Area5 out of 5', 'Amenities5 out of 5'...
# 1  ['Green Area4 out of 5', 'Construction4 out of...
# 2  ['Green Area5 out of 5', 'Construction5 out of...
# 3  ['Green Area4.5 out of 5', 'Construction4.5 ou...
# 4  ['Environment3 out of 5', 'Lifestyle4 out of 5...

# %%
#clean property_name and society columns

df.insert(loc=3,column='sector',value=df['property_name'].str.split('in').str.get(1).str.replace('Gurgaon','').str.strip())

# %%
df.head()
# Out:
#                             property_name property_type               society  \
# 0        4 BHK Flat in Sector 112 Gurgaon          flat   experion windchants
# 1         3 BHK Flat in Sector 67 Gurgaon          flat            m3m merlin
# 2         3 BHK Flat in Sector 65 Gurgaon          flat        m3m golfestate
# 3         2 BHK Flat in Sector 85 Gurgaon          flat           ss the leaf
# 4  5 Bedroom House for sale in Bhim Nagar         house  bhim nagar, sector 6
#
#        sector  price  price_per_sqft    area  \
# 0  Sector 112   5.60         11529.0  4857.0
# 1   Sector 67   2.90         14167.0  2047.0
# 2   Sector 65   6.10         18138.0  3363.0
# 3   Sector 85   1.05          6163.0  1704.0
# 4  Bhim Nagar   0.85        126865.0    67.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0  Super Built up area 4857(451.23 sq.m.)Built Up...        4         6
# 1             Super Built up area 2047(190.17 sq.m.)        3         3
# 2  Super Built up area 3363(312.43 sq.m.)Carpet a...        3         3
# 3             Super Built up area 1671(155.24 sq.m.)        2         2
# 4                           Plot area 67(6.22 sq.m.)        5         2
#
#   balcony           additionalRoom  \
# 0      3+             servant room
# 1       3                   others
# 2       3  study room,servant room
# 3      3+               store room
# 4       2               pooja room
#
#                                              address  floorNum      facing  \
# 0         0000, Sector 112 Gurgaon, Gurgaon, Haryana      15.0  North-East
# 1                Sector 67 Gurgaon, Gurgaon, Haryana       0.0        West
# 2                Sector 65 Gurgaon, Gurgaon, Haryana      19.0  North-East
# 3  Sector 85 Gurgaon, Sector 85 Gurgaon, Gurgaon,...       7.0        West
# 4            H.N0- 159, Bhim Nagar, Gurgaon, Haryana       1.0         NaN
#
#       agePossession                                    nearbyLocations  \
# 0  5 to 10 Year Old  ['Ansal Plaza', 'Dwaraka Expressway', 'First S...
# 1   1 to 5 Year Old  ['Airia Mall', 'Golf Course Extension Road', '...
# 2  5 to 10 Year Old  ['Sector 54 Chowk Metro Station', 'Sahara Mall...
# 3   1 to 5 Year Old  ['Sapphire 83 Mall', 'Dwarka Expressway', 'Cen...
# 4      10+ Year Old  ['Chintapurni Mandir', 'Sheetla Mata Mandir', ...
#
#                                          description  \
# 0  Looking for a 4 bhk property for sale in gurga...
# 1  This 3 bhk flat is located in m3m merlin, whic...
# 2  M3m golfestate is one of gurgaon's most sought...
# 3  Ss the leaf by ss group offers the plan that i...
# 4  Hello all,This is good property where we spent...
#
#                                       furnishDetails  \
# 0  ['5 Wardrobe', '1 Water Purifier', '12 Fan', '...
# 1  ['3 Wardrobe', '5 Fan', '1 Exhaust Fan', '3 Ge...
# 2  ['4 Wardrobe', '5 Fan', '1 Exhaust Fan', '5 Ge...
# 3  ['2 AC', 'No Bed', 'No Chimney', 'No Curtains'...
# 4                                                NaN
#
#                                             features  \
# 0  ['Water purifier', 'Security / Fire Alarm', 'F...
# 1  ['Feng Shui / Vaastu Compliant', 'Security / F...
# 2  ['Centrally Air Conditioned', 'Water purifier'...
# 3  ['Security / Fire Alarm', 'Intercom Facility',...
# 4  ['Water Storage', 'No open drainage around', '...
#
#                                               rating
# 0  ['Green Area5 out of 5', 'Amenities5 out of 5'...
# 1  ['Green Area4 out of 5', 'Construction4 out of...
# 2  ['Green Area5 out of 5', 'Construction5 out of...
# 3  ['Green Area4.5 out of 5', 'Construction4.5 ou...
# 4  ['Environment3 out of 5', 'Lifestyle4 out of 5...

# %%
df['sector']= df['sector'].str.lower()

# %%
#check sector column
df['sector'].value_counts()
# Out:
# sohna                                                        163
# sector 102                                                   113
# sector 85                                                    110
# sector 92                                                    104
# sector 69                                                     94
# sector 65                                                     90
# sector 90                                                     90
# sector 81                                                     90
# sector 109                                                    88
# sector 79                                                     80
# sector 83                                                     69
# sector 37d                                                    68
# sector 86                                                     67
# sector 104                                                    66
# sector 107                                                    60
# sector 108                                                    59
# sector 56                                                     57
# sector 95                                                     57
# sector 48                                                     56
# sector 89                                                     56
# sector 70a                                                    54
# nirvana country                                               53
# sector 70                                                     53
# sector 37c                                                    53
# sector 84                                                     51
# sector-33 sohna                                               51
# palam vihar                                                   50
# sector 67                                                     48
# sector 66                                                     46
# sector 103                                                    45
# dlf phase 2                                                   43
# dlf phase 1                                                   43
# sector 113                                                    43
# sector 82                                                     42
# sector 61                                                     42
# sector 106                                                    38
# sector 49                                                     36
# sector 99a                                                    32
# sushant lok phase 1                                           31
# sector 68                                                     30
# sector 77                                                     29
# sector 72                                                     29
# sector 54                                                     27
# laxman vihar                                                  27
# sector 71                                                     27
# dlf phase 4                                                   26
# sector 112                                                    24
# sector 88a                                                    23
# sector 33                                                     23
# sector 67a                                                    22
# dlf phase 3                                                   22
# sector 111                                                    22
# sector 82a                                                    20
# sector 22                                                     20
# sector 78                                                     19
# sector 74                                                     18
# sector 63a                                                    18
# sector 91                                                     17
# sector 62                                                     17
# sector 99                                                     16
# sector 110                                                    16
# sushant lok phase 3                                           16
# sector 14                                                     15
# sector 63                                                     15
# sector 60                                                     15
# rajendra park                                                 14
# sector 1 imt manesar                                          14
# sector 52                                                     14
# sector 53                                                     14
# dlf phase 5                                                   14
# sector 3                                                      14
# sector 76                                                     14
# gwal pahari                                                   14
# laxman vihar phase 2                                          13
# sector 46                                                     13
# sector 36a                                                    13
# sector 39                                                     12
# sector 50                                                     12
# sector 31                                                     12
# sector 38                                                     12
# uppals southend                                               12
# sector 93                                                     12
# sohna road                                                    12
# sector 47                                                     11
# ashok vihar phase 3 extension                                 11
# sector 9a                                                     11
# sector 7                                                      10
# sector 1a imt manesar                                         10
# sector 55                                                      9
# south city 1                                                   9
# ashok vihar phase 2                                            9
# sector 95a                                                     9
# sector 4                                                       9
# sector 57                                                      8
# dwarka expressway                                              8
# c block sushant lok phase 1                                    8
# mehrauli  road                                                 8
# malibu town                                                    8
# sector 10a                                                     8
# sector 59                                                      8
# sector 43                                                      8
# sector 89 a                                                    8
# sector 40                                                      8
# palam vihar extension                                          8
# sector 58                                                      7
# sector 51                                                      7
# new colony                                                     7
# mianwali colony                                                7
# sector 36 sohna                                                7
# sector 26                                                      7
# sector 11                                                      7
# surat nagar 1                                                  7
# rajiv nagar                                                    6
# jyoti park                                                     6
# jacobpura                                                      6
# ashok vihar                                                    6
# sector 1                                                       6
# sector 5                                                       6
# ansal plaza                                                    5
# sector 28                                                      5
# saraswati vihar                                                5
# sector 9                                                       5
# manesar                                                        5
# arjun nagar                                                    5
# sushant lok phase 2                                            5
# dayanand colony                                                5
# sector 30                                                      5
# sector 105                                                     5
# sector 2                                                       5
# new palam vihar                                                5
# sector 80                                                      5
# sector 23a                                                     5
# chakkarpur                                                     5
# subhash nagar                                                  5
# greenwood city                                                 5
# sector 6                                                       4
# sector 3a                                                      4
# garhi harsaru                                                  4
# shivpuri                                                       4
# shivaji nagar                                                  4
# ravi nagar                                                     4
# madanpuri                                                      4
# sector 17                                                      4
# sector 36                                                      4
# imt manesar                                                    4
# sector 12                                                      4
# adarsh nagar                                                   4
# sector 12a                                                     4
# dharam colony                                                  4
# krishna colony                                                 4
# suncity                                                        4
# baldev nagar                                                   4
# devilal colony                                                 4
# surya vihar                                                    4
# new                                                            4
# bhim nagar                                                     4
# valley view estate                                             4
# vishnu garden                                                  4
# bhondsi                                                        4
# sector 45                                                      4
# sector 27                                                      3
# patel nagar                                                    3
# laxmi garden                                                   3
# mg road                                                        3
# b block sushant lok phase 1                                    3
# sector 8                                                       3
# sector 17a                                                     3
# sector 110 a                                                   3
# prem nagar                                                     3
# maruti kunj                                                    3
# gandhi nagar                                                   3
# sector 15                                                      3
# shakti nagar                                                   3
# sector 88b                                                     3
# sector 17b                                                     3
# sector 23                                                      3
# sector 73                                                      3
# a block sushant lok phase 1                                    3
# rosewood                                                       2
# farukhnagar                                                    2
# nars                                                           2
# sector-2 sohna                                                 2
# , delhi ncr                                                    2
# sispal vihar                                                   2
# sohna  road                                                    2
# block a surya vihar                                            2
# samaspur                                                       2
# new palam vihar phase 2                                        2
# sector 41                                                      2
# sector-11 sohna                                                2
# mohan nagar                                                    2
# sheetla colony                                                 2
# bissar                                                         2
# shankar vihar                                                  2
# pratap nagar                                                   2
# hira nagar                                                     2
# sector 15 part 1                                               2
# sector 32                                                      2
# surat nagar phase 2                                            2
# mayfield garden                                                2
# manohar nagar                                                  2
# iffco chowk                                                    2
# surat nagar                                                    2
# shanti nagar                                                   2
# west rajiv nagar                                               2
# golf course road                                               2
# sector 15 part 2                                               2
# sector 24                                                      2
# new basti                                                      2
# golf course ext road                                           2
# sector 21                                                      2
# bhawani enclave                                                2
# daulatabad                                                     2
# sushant lok                                                    2
# acharya puri                                                   2
# faridabad road                                                 2
# ambience island                                                2
# lajpat nagar                                                   2
# rajiv chowk                                                    2
# new palam vihar phase 1                                        2
# gopal nagar, garhi ghasita, sonipat                            1
# shivji park colony                                             1
# sai kunj                                                       1
# carterpuri village                                             1
# ram nagar                                                      1
# part 3 sector 5                                                1
# cyber city                                                     1
# saraswati enclave                                              1
# huda saraswati vihar                                           1
# sector 21a faridabad                                           1
# bptp                                                           1
# kanahi                                                         1
# lucknow                                                        1
# naharpur rupa                                                  1
# g block dlf city phase 1                                       1
# b1 block sector 57                                             1
# new jyoti park                                                 1
# sadar bazar                                                    1
# ansal's palam vihar                                            1
# sector 17c                                                     1
# garauli kalan                                                  1
# kheri                                                          1
# tekchand nagar                                                 1
# nirvana country pocket h                                       1
# dhankot                                                        1
# old delhi road, opp sector-14                                  1
# ashok vihar phase 3                                            1
# laxman vihar, railway road,                                    1
# udyog vihar phase 1                                            1
# alipur                                                         1
# ashok vihar phase i                                            1
# rajiv colony                                                   1
# devi lal colony gali no 12 gurgaon nr omkar public school      1
# jat colony,fazilpur/taj nagar road                             1
# pataudi road                                                   1
# khandsa                                                        1
# om nagar                                                       1
# sultanpur                                                      1
# sector 37a                                                     1
# sector-35 sohna                                                1
# hno 13 sagar enclave sura                                      1
# damdma                                                         1
# sector 13                                                      1
# ats marigold                                                   1
# sec 3 bhim vihar part 1 bhimgher kheri                         1
# mahavir pura                                                   1
# hsiidc plot sector 1 imt manesar                               1
# park view                                                      1
# near sector 1 market                                           1
# sector 9b                                                      1
# rattan garden                                                  1
# sector 42                                                      1
# bhora kalan                                                    1
# mahalaxmi garden, rajendra place                               1
# sector-5 sheetla colony                                        1
# v block dlf phase 3                                            1
# heritage city                                                  1
# urban estate, sector 5                                         1
# bhimgarh kheri phase 3                                         1
# vir nagar                                                      1
# block g sector-57                                              1
# civil l                                                        1
# sector 5 chowk                                                 1
# sector-5 sohna                                                 1
# jacobpura near sadar bazar                                     1
# new colony, sector 7                                           1
# anand garden, sector-105                                       1
# sector 37b                                                     1
# south city                                                     1
# near khandsa road                                              1
# near pataudi chowk                                             1
# ravi nager basai road                                          1
# begampur khatola                                               1
# laxmna vihar, phase 2                                          1
# sector-7 hous                                                  1
# block h ashok vihar phase iii extension                        1
# saroop garden rajendra park                                    1
# sector 4 urban estate                                          1
# near euro                                                      1
# near nand hospital                                             1
# godrej aria , sector 79 ,                                      1
# Name: sector, dtype: int64

# %%
#now we have to find sector number of that perticular area like laxman vihar
df['sector'] = df['sector'].str.replace('dharam colony','sector 12')
df['sector'] = df['sector'].str.replace('krishna colony','sector 7')
df['sector'] = df['sector'].str.replace('suncity','sector 54')
df['sector'] = df['sector'].str.replace('prem nagar','sector 13')
df['sector'] = df['sector'].str.replace('mg road','sector 28')
df['sector'] = df['sector'].str.replace('gandhi nagar','sector 28')
df['sector'] = df['sector'].str.replace('laxmi garden','sector 11')
df['sector'] = df['sector'].str.replace('shakti nagar','sector 11')

# %%
df['sector'] = df['sector'].str.replace('baldev nagar','sector 7')
df['sector'] = df['sector'].str.replace('shivpuri','sector 7')
df['sector'] = df['sector'].str.replace('garhi harsaru','sector 17')
df['sector'] = df['sector'].str.replace('imt manesar','manesar')
df['sector'] = df['sector'].str.replace('adarsh nagar','sector 12')
df['sector'] = df['sector'].str.replace('shivaji nagar','sector 11')
df['sector'] = df['sector'].str.replace('bhim nagar','sector 6')
df['sector'] = df['sector'].str.replace('madanpuri','sector 7')

# %%
df['sector'] = df['sector'].str.replace('saraswati vihar','sector 28')
df['sector'] = df['sector'].str.replace('arjun nagar','sector 8')
df['sector'] = df['sector'].str.replace('ravi nagar','sector 9')
df['sector'] = df['sector'].str.replace('vishnu garden','sector 105')
df['sector'] = df['sector'].str.replace('bhondsi','sector 11')
df['sector'] = df['sector'].str.replace('surya vihar','sector 21')
df['sector'] = df['sector'].str.replace('devilal colony','sector 9')
df['sector'] = df['sector'].str.replace('valley view estate','gwal pahari')

# %%
df['sector'] = df['sector'].str.replace('mehrauli  road','sector 14')
df['sector'] = df['sector'].str.replace('jyoti park','sector 7')
df['sector'] = df['sector'].str.replace('ansal plaza','sector 23')
df['sector'] = df['sector'].str.replace('dayanand colony','sector 6')
df['sector'] = df['sector'].str.replace('sushant lok phase 2','sector 55')
df['sector'] = df['sector'].str.replace('chakkarpur','sector 28')
df['sector'] = df['sector'].str.replace('greenwood city','sector 45')
df['sector'] = df['sector'].str.replace('subhash nagar','sector 12')

# %%
df['sector'] = df['sector'].str.replace('sohna road road','sohna road')
df['sector'] = df['sector'].str.replace('malibu town','sector 47')
df['sector'] = df['sector'].str.replace('surat nagar 1','sector 104')
df['sector'] = df['sector'].str.replace('new colony','sector 7')
df['sector'] = df['sector'].str.replace('mianwali colony','sector 12')
df['sector'] = df['sector'].str.replace('jacobpura','sector 12')
df['sector'] = df['sector'].str.replace('rajiv nagar','sector 13')
df['sector'] = df['sector'].str.replace('ashok vihar','sector 3')

# %%
df['sector'] = df['sector'].str.replace('dlf phase 1','sector 26')
df['sector'] = df['sector'].str.replace('nirvana country','sector 50')
df['sector'] = df['sector'].str.replace('palam vihar','sector 2')
df['sector'] = df['sector'].str.replace('dlf phase 2','sector 25')
df['sector'] = df['sector'].str.replace('sushant lok phase 1','sector 43')
df['sector'] = df['sector'].str.replace('laxman vihar','sector 4')
df['sector'] = df['sector'].str.replace('dlf phase 4','sector 28')
df['sector'] = df['sector'].str.replace('dlf phase 3','sector 24')

# %%
df['sector'] = df['sector'].str.replace('sushant lok phase 3','sector 57')
df['sector'] = df['sector'].str.replace('dlf phase 5','sector 43')
df['sector'] = df['sector'].str.replace('rajendra park','sector 105')
df['sector'] = df['sector'].str.replace('uppals southend','sector 49')
df['sector'] = df['sector'].str.replace('sohna','sohna road')
df['sector'] = df['sector'].str.replace('ashok vihar phase 3 extension','sector 5')
df['sector'] = df['sector'].str.replace('south city 1','sector 41')
df['sector'] = df['sector'].str.replace('ashok vihar phase 2','sector 5')

# %%
df['sector'].value_counts()
# Out:
# sohna road                                                   163
# sector 102                                                   113
# sector 85                                                    110
# sector 92                                                    104
# sector 69                                                     94
# sector 90                                                     90
# sector 65                                                     90
# sector 81                                                     90
# sector 109                                                    88
# sector 79                                                     80
# sector 104                                                    73
# sector 83                                                     69
# sector 37d                                                    68
# sector 86                                                     67
# sector 50                                                     65
# sector 107                                                    60
# sector 108                                                    59
# sector 95                                                     57
# sector 56                                                     57
# sector 48                                                     56
# sector 89                                                     56
# sector 2                                                      55
# sector 70a                                                    54
# sector 43                                                     53
# sector 70                                                     53
# sector 37c                                                    53
# sector-33 sohna road                                          51
# sector 84                                                     51
# sector 26                                                     50
# sector 67                                                     48
# sector 49                                                     48
# sector 28                                                     47
# sector 66                                                     46
# sector 103                                                    45
# sector 25                                                     43
# sector 113                                                    43
# sector 61                                                     42
# sector 82                                                     42
# sector 7                                                      39
# sector 106                                                    38
# sector 4                                                      36
# sector 99a                                                    32
# sector 54                                                     31
# sector 12                                                     30
# sector 68                                                     30
# sector 72                                                     29
# sector 77                                                     29
# sector 71                                                     27
# sector 57                                                     24
# sector 24                                                     24
# sector 112                                                    24
# sector 88a                                                    23
# sector 14                                                     23
# sector 105                                                    23
# sector 33                                                     23
# sector 67a                                                    22
# sector 111                                                    22
# sector 11                                                     21
# sector 3                                                      20
# sector 22                                                     20
# sector 82a                                                    20
# sector 78                                                     19
# sector 47                                                     19
# gwal pahari                                                   18
# sector 63a                                                    18
# sector 74                                                     18
# sector 62                                                     17
# sector 91                                                     17
# sector 99                                                     16
# sector 110                                                    16
# sector 63                                                     15
# sector 60                                                     15
# sector 76                                                     14
# sector 55                                                     14
# sector 53                                                     14
# sector 1 manesar                                              14
# sector 52                                                     14
# sector 6                                                      13
# sector 36a                                                    13
# sector 4 phase 2                                              13
# sector 9                                                      13
# sector 46                                                     13
# sector 39                                                     12
# sector 38                                                     12
# sector 93                                                     12
# sohna road road                                               12
# sector 31                                                     12
# sector 41                                                     11
# sector 3 phase 3 extension                                    11
# sector 9a                                                     11
# sector 1a manesar                                             10
# sector 13                                                     10
# sector 95a                                                     9
# sector 45                                                      9
# manesar                                                        9
# sector 3 phase 2                                               9
# sector 2 extension                                             8
# dwarka expressway                                              8
# sector 17                                                      8
# sector 59                                                      8
# sector 40                                                      8
# sector 23                                                      8
# sector 10a                                                     8
# sector 89 a                                                    8
# sector 8                                                       8
# c block sector 43                                              8
# sector 36 sohna road                                           7
# sector 51                                                      7
# sector 58                                                      7
# sector 1                                                       6
# sector 5                                                       6
# sector 21                                                      6
# sector 23a                                                     5
# sector 80                                                      5
# sector 30                                                      5
# new sector 2                                                   5
# sector 12a                                                     4
# sector 3a                                                      4
# new                                                            4
# sector 36                                                      4
# sector 73                                                      3
# sector 88b                                                     3
# sector 17b                                                     3
# sector 17a                                                     3
# b block sector 43                                              3
# sector 27                                                      3
# sector 110 a                                                   3
# a block sector 43                                              3
# patel nagar                                                    3
# sector 15                                                      3
# maruti kunj                                                    3
# sector 15 part 1                                               2
# ambience island                                                2
# manohar nagar                                                  2
# new sector 2 phase 1                                           2
# new basti                                                      2
# pratap nagar                                                   2
# hira nagar                                                     2
# surat nagar phase 2                                            2
# mohan nagar                                                    2
# faridabad road                                                 2
# sector-2 sohna road                                            2
# sohna road  road                                               2
# surat nagar                                                    2
# shanti nagar                                                   2
# samaspur                                                       2
# rosewood                                                       2
# new sector 2 phase 2                                           2
# acharya puri                                                   2
# block a sector 21                                              2
# farukhnagar                                                    2
# sispal vihar                                                   2
# mayfield garden                                                2
# , delhi ncr                                                    2
# sector 32                                                      2
# iffco chowk                                                    2
# nars                                                           2
# sector-11 sohna road                                           2
# lajpat nagar                                                   2
# golf course ext road                                           2
# sushant lok                                                    2
# bhawani enclave                                                2
# shankar vihar                                                  2
# sector 15 part 2                                               2
# rajiv chowk                                                    2
# daulatabad                                                     2
# golf course road                                               2
# west sector 13                                                 2
# sheetla colony                                                 2
# bissar                                                         2
# shivji park colony                                             1
# sultanpur                                                      1
# lucknow                                                        1
# huda sector 28                                                 1
# sai kunj                                                       1
# devi lal colony gali no 12 gurgaon nr omkar public school      1
# gopal nagar, garhi ghasita, sonipat                            1
# carterpuri village                                             1
# ram nagar                                                      1
# kanahi                                                         1
# cyber city                                                     1
# rajiv colony                                                   1
# old delhi road, opp sector-14                                  1
# sector 4, railway road,                                        1
# khandsa                                                        1
# naharpur rupa                                                  1
# alipur                                                         1
# tekchand nagar                                                 1
# saraswati enclave                                              1
# sector 17c                                                     1
# sector 3 phase i                                               1
# b1 block sector 57                                             1
# sector 21a faridabad                                           1
# bptp                                                           1
# udyog vihar phase 1                                            1
# part 3 sector 5                                                1
# pataudi road                                                   1
# garauli kalan                                                  1
# new sector 7                                                   1
# kheri                                                          1
# sector 50 pocket h                                             1
# jat colony,fazilpur/taj nagar road                             1
# ansal's sector 2                                               1
# dhankot                                                        1
# sadar bazar                                                    1
# sector 3 phase 3                                               1
# g block dlf city phase 1                                       1
# near sector 1 market                                           1
# sector 37a                                                     1
# om nagar                                                       1
# sector-35 sohna road                                           1
# hno 13 sagar enclave sura                                      1
# damdma                                                         1
# ats marigold                                                   1
# sec 3 bhim vihar part 1 bhimgher kheri                         1
# mahavir pura                                                   1
# hsiidc plot sector 1 manesar                                   1
# park view                                                      1
# sector 9b                                                      1
# sector 5 chowk                                                 1
# rattan garden                                                  1
# sector 42                                                      1
# bhora kalan                                                    1
# mahasector 11, rajendra place                                  1
# sector-5 sheetla colony                                        1
# v block sector 24                                              1
# heritage city                                                  1
# urban estate, sector 5                                         1
# bhimgarh kheri phase 3                                         1
# vir nagar                                                      1
# block g sector-57                                              1
# ravi nager basai road                                          1
# sector-5 sohna road                                            1
# sector 12 near sadar bazar                                     1
# sector 7, sector 7                                             1
# anand garden, sector-105                                       1
# sector 37b                                                     1
# south city                                                     1
# near khandsa road                                              1
# civil l                                                        1
# near pataudi chowk                                             1
# begampur khatola                                               1
# laxmna vihar, phase 2                                          1
# sector-7 hous                                                  1
# block h sector 3 phase iii extension                           1
# saroop garden sector 105                                       1
# sector 4 urban estate                                          1
# near euro                                                      1
# near nand hospital                                             1
# godrej aria , sector 79 ,                                      1
# Name: sector, dtype: int64

# %%
df['sector'] = df['sector'].str.replace('sector 95a','sector 95')
df['sector'] = df['sector'].str.replace('sector 23a','sector 23')
df['sector'] = df['sector'].str.replace('sector 12a','sector 12')
df['sector'] = df['sector'].str.replace('sector 3a','sector 3')
df['sector'] = df['sector'].str.replace('sector 110 a','sector 110')
df['sector'] = df['sector'].str.replace('patel nagar','sector 15')
df['sector'] = df['sector'].str.replace('a block sector 43','sector 43')
df['sector'] = df['sector'].str.replace('maruti kunj','sector 12')
df['sector'] = df['sector'].str.replace('b block sector 43','sector 43')

# %%
df['sector'] = df['sector'].str.replace('sector-33 sohna road','sector 33')
df['sector'] = df['sector'].str.replace('sector 1 manesar','manesar')
df['sector'] = df['sector'].str.replace('sector 4 phase 2','sector 4')
df['sector'] = df['sector'].str.replace('sector 1a manesar','manesar')
df['sector'] = df['sector'].str.replace('c block sector 43','sector 43')
df['sector'] = df['sector'].str.replace('sector 89 a','sector 89')
df['sector'] = df['sector'].str.replace('sector 2 extension','sector 2')
df['sector'] = df['sector'].str.replace('sector 36 sohna road','sector 36')

# %%
a = df['sector'].value_counts()[df['sector'].value_counts() >= 3]
df = df[df['sector'].isin(a.index)]

# %%
df['sector'].value_counts()
# Out:
# sohna road                    163
# sector 102                    113
# sector 85                     110
# sector 92                     105
# sector 69                      94
# sector 90                      91
# sector 81                      90
# sector 65                      90
# sector 109                     88
# sector 79                      80
# sector 33                      74
# sector 104                     73
# sector 83                      69
# sector 37d                     67
# sector 43                      67
# sector 86                      67
# sector 95                      66
# sector 50                      65
# sector 89                      64
# sector 2                       63
# sector 107                     60
# sector 108                     59
# sector 56                      57
# sector 48                      56
# sector 70a                     54
# sector 37c                     53
# sector 70                      53
# sector 84                      50
# sector 26                      50
# sector 4                       49
# sector 67                      48
# sector 28                      47
# sector 49                      47
# sector 66                      46
# sector 103                     45
# sector 113                     43
# sector 25                      43
# sector 82                      42
# sector 61                      42
# sector 7                       39
# sector 12                      37
# sector 106                     37
# manesar                        33
# sector 99a                     32
# sector 54                      31
# sector 68                      29
# sector 72                      29
# sector 77                      28
# sector 71                      27
# sector 24                      24
# sector 57                      24
# sector 3                       24
# sector 112                     24
# sector 110                     24
# sector 88a                     23
# sector 105                     23
# sector 14                      23
# sector 111                     22
# sector 67a                     22
# sector 11                      21
# sector 82a                     20
# sector 78                      19
# sector 22                      19
# sector 47                      19
# gwal pahari                    18
# sector 74                      18
# sector 63a                     18
# sector 62                      17
# sector 99                      16
# sector 91                      16
# sector 76                      15
# sector 60                      15
# sector 63                      15
# sector 55                      14
# sector 52                      14
# sector 53                      14
# sector 46                      13
# sector 9                       13
# sector 36a                     13
# sector 6                       13
# sector 23                      13
# sector 38                      12
# sector 31                      12
# sector 39                      12
# sohna road road                12
# sector 93                      12
# sector 3 phase 3 extension     11
# sector 36                      11
# sector 41                      11
# sector 13                      10
# sector 9a                      10
# sector 3 phase 2                9
# sector 45                       9
# sector 59                       8
# sector 40                       8
# sector 17                       8
# sector 10a                      8
# sector 8                        8
# dwarka expressway               8
# sector 51                       7
# sector 58                       7
# sector 1                        6
# sector 15                       6
# sector 21                       6
# sector 5                        6
# sector 30                       5
# new sector 2                    5
# sector 80                       5
# new                             4
# sector 88b                      3
# sector 17b                      3
# sector 27                       3
# sector 17a                      3
# sector 73                       3
# Name: sector, dtype: int64

# %%
df[df['sector'] == 'new']
# Out:
#      property_type                       society sector  price  \
# 373           flat                    sare homes    new   0.85
# 1685          flat                        dlf 76    new   4.00
# 2266          flat  takshila heights sector 37 c    new   0.67
# 3318          flat                   green court    new   0.38
#
#       price_per_sqft    area                            areaWithType  bedRoom  \
# 373           4786.0  1776.0     Super Built up area 1776(165 sq.m.)        4
# 1685         11428.0  3500.0        Carpet area: 3500 (325.16 sq.m.)        4
# 2266          5583.0  1200.0  Super Built up area 1200(111.48 sq.m.)        2
# 3318          5507.0   690.0           Carpet area: 690 (64.1 sq.m.)        2
#
#       bathroom balcony           additionalRoom  floorNum facing  \
# 373          4       3            not available       3.0    NaN
# 1685         4       2  study room,servant room       4.0    NaN
# 2266         2       2            not available       3.0    NaN
# 3318         2       1            not available       7.0    NaN
#
#            agePossession                                    nearbyLocations  \
# 373     5 to 10 Year Old  ['Columbia Asia Hospital', 'Apex Multi Special...
# 1685            Jun 2027  ['Shri Balaji Hospital and Trauma Center', 'S....
# 2266     1 to 5 Year Old  ['Shri Balaji Hospital and Trauma Center', 'S....
# 3318  Under Construction  ['Ing bank ATM', 'Dcb bank ATM', 'Indus ind ba...
#
#                                          furnishDetails  \
# 373                                                  []
# 1685  ['6 Wardrobe', '1 Fridge', '8 Fan', '1 Exhaust...
# 2266                                                 []
# 3318                                                 []
#
#                                                features
# 373                                                 NaN
# 1685  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...
# 2266  ['Lift(s)', 'Swimming Pool', 'Visitor Parking'...
# 3318  ['Intercom Facility', 'Lift(s)', 'Maintenance ...

# %%
df.loc[955,'sector'] = 'sector 37'
df.loc[2800,'sector'] = 'sector 92'
df.loc[2838,'sector'] = 'sector 90'
df.loc[2857,'sector'] = 'sector 76'

# %%
df[df['sector'] == 'new sector 2']
# Out:
#      property_type              society        sector  price  price_per_sqft  \
# 204           flat              my home  new sector 2   0.22          4400.0
# 291          house          independent  new sector 2   1.00          8796.0
# 1439         house              my home  new sector 2   0.34         12592.0
# 3521          flat  ompee k s residency  new sector 2   1.60         26936.0
# 3881          flat              my home  new sector 2   0.28          3166.0
#
#         area                                       areaWithType  bedRoom  \
# 204    500.0                     Carpet area: 500 (46.45 sq.m.)      2.0
# 291   1137.0  Plot area 120(100.34 sq.m.)Built Up area: 120 ...      3.0
# 1439   270.0                         Plot area 270(25.08 sq.m.)      2.0
# 3521   594.0                      Carpet area: 66 (55.18 sq.m.)      2.0
# 3881   884.0                     Carpet area: 900 (83.61 sq.m.)      2.0
#
#       bathroom balcony additionalRoom  floorNum facing     agePossession  \
# 204        2.0       1  not available       1.0    NaN   0 to 1 Year Old
# 291        2.0       2     pooja room       1.0  North      10+ Year Old
# 1439       2.0       2  not available       3.0   West  5 to 10 Year Old
# 3521       2.0       2  not available       1.0    NaN   1 to 5 Year Old
# 3881       1.0       1         others       2.0    NaN   1 to 5 Year Old
#
#                                         nearbyLocations  \
# 204   ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 291   ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 1439  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 3521  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 3881  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
#
#                                          furnishDetails  \
# 204   ['3 Fan', '1 Exhaust Fan', '15 Light', '1 Modu...
# 291                                                 NaN
# 1439  ['1 Wardrobe', '3 Fan', '6 Light', 'No AC', 'N...
# 3521                                                NaN
# 3881  ['3 Wardrobe', '5 Light', '1 Chimney', '1 Modu...
#
#                                           features
# 204                                            NaN
# 291                                            NaN
# 1439  ['Water Storage', 'Park', 'Visitor Parking']
# 3521                                           NaN
# 3881                     ['Water Storage', 'Park']

# %%
df.loc[[311,1072,1486,3040,3875],'sector'] = 'sector 110'

# %%
df['sector'].value_counts()
# Out:
# sohna road                    163
# sector 102                    113
# sector 85                     110
# sector 92                     105
# sector 69                      94
# sector 90                      91
# sector 81                      90
# sector 65                      90
# sector 109                     88
# sector 79                      80
# sector 33                      74
# sector 104                     73
# sector 83                      69
# sector 37d                     67
# sector 43                      67
# sector 86                      67
# sector 95                      66
# sector 50                      65
# sector 89                      64
# sector 2                       63
# sector 107                     60
# sector 108                     59
# sector 56                      57
# sector 48                      56
# sector 70a                     54
# sector 37c                     53
# sector 70                      53
# sector 84                      50
# sector 26                      50
# sector 4                       49
# sector 67                      48
# sector 28                      47
# sector 49                      47
# sector 66                      46
# sector 103                     45
# sector 113                     43
# sector 25                      43
# sector 82                      42
# sector 61                      42
# sector 7                       39
# sector 12                      37
# sector 106                     37
# manesar                        33
# sector 99a                     32
# sector 54                      31
# sector 68                      29
# sector 72                      29
# sector 77                      28
# sector 71                      27
# sector 24                      24
# sector 57                      24
# sector 3                       24
# sector 112                     24
# sector 110                     24
# sector 14                      23
# sector 105                     23
# sector 88a                     23
# sector 111                     22
# sector 67a                     22
# sector 11                      21
# sector 82a                     20
# sector 78                      19
# sector 22                      19
# sector 47                      19
# sector 63a                     18
# sector 74                      18
# gwal pahari                    18
# sector 62                      17
# sector 99                      16
# sector 91                      16
# sector 60                      15
# sector 76                      15
# sector 63                      15
# sector 52                      14
# sector 53                      14
# sector 55                      14
# sector 46                      13
# sector 36a                     13
# sector 9                       13
# sector 6                       13
# sector 23                      13
# sector 38                      12
# sector 93                      12
# sector 31                      12
# sohna road road                12
# sector 39                      12
# sector 3 phase 3 extension     11
# sector 41                      11
# sector 36                      11
# sector 13                      10
# sector 9a                      10
# sector 3 phase 2                9
# sector 45                       9
# sector 59                       8
# sector 40                       8
# sector 17                       8
# sector 10a                      8
# sector 8                        8
# dwarka expressway               8
# sector 51                       7
# sector 58                       7
# sector 1                        6
# sector 15                       6
# sector 21                       6
# sector 5                        6
# sector 30                       5
# new sector 2                    5
# sector 80                       5
# new                             4
# sector 88b                      3
# sector 17b                      3
# sector 27                       3
# sector 17a                      3
# sector 73                       3
# sector 37                       1
# Name: sector, dtype: int64

# %%
df.shape
# Out:
# (3803, 17)

# %%
df.duplicated().sum()
# Out:
# 122

# %%
df.head()
# Out:
#   property_type               society      sector  price  price_per_sqft  \
# 0          flat   experion windchants  sector 112   5.60         11529.0
# 1          flat            m3m merlin   sector 67   2.90         14167.0
# 2          flat        m3m golfestate   sector 65   6.10         18138.0
# 3          flat           ss the leaf   sector 85   1.05          6163.0
# 4         house  bhim nagar, sector 6    sector 6   0.85        126865.0
#
#      area                                       areaWithType  bedRoom  \
# 0  4857.0  Super Built up area 4857(451.23 sq.m.)Built Up...      4.0
# 1  2047.0             Super Built up area 2047(190.17 sq.m.)      3.0
# 2  3363.0  Super Built up area 3363(312.43 sq.m.)Carpet a...      3.0
# 3  1704.0             Super Built up area 1671(155.24 sq.m.)      2.0
# 4    67.0                           Plot area 67(6.22 sq.m.)      5.0
#
#    bathroom balcony           additionalRoom  floorNum      facing  \
# 0       6.0      3+             servant room      15.0  North-East
# 1       3.0       3                   others       0.0        West
# 2       3.0       3  study room,servant room      19.0  North-East
# 3       2.0      3+               store room       7.0        West
# 4       2.0       2               pooja room       1.0         NaN
#
#       agePossession                                    nearbyLocations  \
# 0  5 to 10 Year Old  ['Ansal Plaza', 'Dwaraka Expressway', 'First S...
# 1   1 to 5 Year Old  ['Airia Mall', 'Golf Course Extension Road', '...
# 2  5 to 10 Year Old  ['Sector 54 Chowk Metro Station', 'Sahara Mall...
# 3   1 to 5 Year Old  ['Sapphire 83 Mall', 'Dwarka Expressway', 'Cen...
# 4      10+ Year Old  ['Chintapurni Mandir', 'Sheetla Mata Mandir', ...
#
#                                       furnishDetails  \
# 0  ['5 Wardrobe', '1 Water Purifier', '12 Fan', '...
# 1  ['3 Wardrobe', '5 Fan', '1 Exhaust Fan', '3 Ge...
# 2  ['4 Wardrobe', '5 Fan', '1 Exhaust Fan', '5 Ge...
# 3  ['2 AC', 'No Bed', 'No Chimney', 'No Curtains'...
# 4                                                NaN
#
#                                             features
# 0  ['Water purifier', 'Security / Fire Alarm', 'F...
# 1  ['Feng Shui / Vaastu Compliant', 'Security / F...
# 2  ['Centrally Air Conditioned', 'Water purifier'...
# 3  ['Security / Fire Alarm', 'Intercom Facility',...
# 4  ['Water Storage', 'No open drainage around', '...

# %%
# features to drop -> property_name, address, description, rating
df.drop(columns=['property_name', 'address', 'description', 'rating'],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-9a7bd0f7d321> in <cell line: 2>()
#       1 # features to drop -> property_name, address, description, rating
# ----> 2 df.drop(columns=['property_name', 'address', 'description', 'rating'],inplace=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503         for axis, labels in axes.items():
#    4504             if labels is not None:
# -> 4505                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4506
#    4507         if inplace:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4544                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4545             else:
# -> 4546                 new_axis = axis.drop(labels, errors=errors)
#    4547             indexer = axis.get_indexer(new_axis)
#    4548
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6932         if mask.any():
#    6933             if errors != "ignore":
# -> 6934                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6935             indexer = indexer[~mask]
#    6936         return self.delete(indexer)
#
# KeyError: "['property_name', 'address', 'description', 'rating'] not found in axis"

# %%
df.head()
# Out:
#   property_type               society      sector  price  price_per_sqft  \
# 0          flat   experion windchants  sector 112   5.60         11529.0
# 1          flat            m3m merlin   sector 67   2.90         14167.0
# 2          flat        m3m golfestate   sector 65   6.10         18138.0
# 3          flat           ss the leaf   sector 85   1.05          6163.0
# 4         house  bhim nagar, sector 6    sector 6   0.85        126865.0
#
#      area                                       areaWithType  bedRoom  \
# 0  4857.0  Super Built up area 4857(451.23 sq.m.)Built Up...      4.0
# 1  2047.0             Super Built up area 2047(190.17 sq.m.)      3.0
# 2  3363.0  Super Built up area 3363(312.43 sq.m.)Carpet a...      3.0
# 3  1704.0             Super Built up area 1671(155.24 sq.m.)      2.0
# 4    67.0                           Plot area 67(6.22 sq.m.)      5.0
#
#    bathroom balcony           additionalRoom  floorNum      facing  \
# 0       6.0      3+             servant room      15.0  North-East
# 1       3.0       3                   others       0.0        West
# 2       3.0       3  study room,servant room      19.0  North-East
# 3       2.0      3+               store room       7.0        West
# 4       2.0       2               pooja room       1.0         NaN
#
#       agePossession                                    nearbyLocations  \
# 0  5 to 10 Year Old  ['Ansal Plaza', 'Dwaraka Expressway', 'First S...
# 1   1 to 5 Year Old  ['Airia Mall', 'Golf Course Extension Road', '...
# 2  5 to 10 Year Old  ['Sector 54 Chowk Metro Station', 'Sahara Mall...
# 3   1 to 5 Year Old  ['Sapphire 83 Mall', 'Dwarka Expressway', 'Cen...
# 4      10+ Year Old  ['Chintapurni Mandir', 'Sheetla Mata Mandir', ...
#
#                                       furnishDetails  \
# 0  ['5 Wardrobe', '1 Water Purifier', '12 Fan', '...
# 1  ['3 Wardrobe', '5 Fan', '1 Exhaust Fan', '3 Ge...
# 2  ['4 Wardrobe', '5 Fan', '1 Exhaust Fan', '5 Ge...
# 3  ['2 AC', 'No Bed', 'No Chimney', 'No Curtains'...
# 4                                                NaN
#
#                                             features
# 0  ['Water purifier', 'Security / Fire Alarm', 'F...
# 1  ['Feng Shui / Vaastu Compliant', 'Security / F...
# 2  ['Centrally Air Conditioned', 'Water purifier'...
# 3  ['Security / Fire Alarm', 'Intercom Facility',...
# 4  ['Water Storage', 'No open drainage around', '...

# %%
df.shape
# Out:
# (3803, 17)

# %%
#now we clean all most data but we have to apply feature engineering on => 'areaWithType', agePossession, nearbyLocations, facing like that

# %%
#Extrack this clean data into csv file
df.to_csv('gurgaon_properties_cleaned_v1j.csv', index=False)

# %%
# Download the CSV file from Colab to your local machine
from google.colab import files
files.download('gurgaon_properties_cleaned_v1j.csv')
